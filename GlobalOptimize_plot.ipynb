# %%
# 目前结合之后，收敛速度更快，但是精度不如grad 考虑降低ld，或提高decayN

# %%
import os
# import shutil
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
def show1(x:list, file3:str, name="", mod = 0):
    
    font1 = {
        'weight' : 'normal',
        'size'   : 20,
    }
    
    #---------------- acc ----------------#
    file_path = f"./saved_exp_info_0/server_acc/"
    file_path3 = f"./saved_exp_info/server_acc/"
    
    inf = []
    for i in range(len(x)):
        inf.append(np.array(pickle.load(open(file_path + x[i], 'rb')), dtype=object))
    
    plt.figure(figsize=(16, 9)) # 设置整个图像的尺寸（长高分别为6、5个单位）
    plt.title(f"{name}_acc",fontsize=24)
    plt.ylabel('accuracy',fontsize=20)
    plt.xlabel('iteration',fontsize=20)
    
    plt.plot(inf[0],label = "FedAvg")
    plt.plot(inf[1],label = "FedProx")
#     plt.plot(inf[2],label = "ShannonTao")
    plt.plot(inf[4],label = "ShannonWeight")
    plt.plot(inf[3],label = "Grad")
    
    plt.plot(np.array(pickle.load(open(file_path3 + file3, 'rb')), dtype=object),label = "pFedDGD") # 对比

    plt.legend(loc = "lower right", prop=font1) # 设置信息框    
    
    if mod == 0:
        plt.show()
    else:
        plt.savefig(f"./pic/{name}_acc.png", dpi=300, bbox_inches='tight')
    
    #---------------- loss ----------------#
    file_path = f"./saved_exp_info_0/server_loss/"
    file_path3 = f"./saved_exp_info/server_loss/"
    
    inf = []
    for i in range(len(x)):
        inf.append(np.array(pickle.load(open(file_path + x[i], 'rb')), dtype=object))
    
    plt.figure(figsize=(16, 9)) # 设置整个图像的尺寸（长高分别为6、5个单位）
    plt.title(f"{name}_loss",fontsize=24)
    plt.ylabel('accuracy',fontsize=20)
    plt.xlabel('iteration',fontsize=20)
    
    plt.plot(inf[0],label = "FedAvg")
    plt.plot(inf[1],label = "FedProx")
#     plt.plot(inf[2],label = "ShannonTao")
    plt.plot(inf[4],label = "ShannonWeight")
    plt.plot(inf[3],label = "Grad")
    
    plt.plot(np.array(pickle.load(open(file_path3 + file3, 'rb')), dtype=object),label = "pFedDGD") #对比
    
    plt.legend(loc = "upper right", prop=font1) # 设置信息框    

    if mod == 0:
        plt.show()
    else:
        plt.savefig(f"./pic/{name}_loss.png", dpi=300, bbox_inches='tight')

# %%
def show2(x:list, file3:str, name="", mod = 0):
    
    font1 = {
        'weight' : 'normal',
        'size'   : 20,
    }
    
    #---------------- acc ----------------#
    file_path = f"./saved_exp_info/server_acc/"
    
    inf = []
    for i in range(len(x)):
        inf.append(np.array(pickle.load(open(file_path + x[i], 'rb')), dtype=object))
    
    plt.figure(figsize=(16, 9)) # 设置整个图像的尺寸（长高分别为6、5个单位）
    plt.title(f"{name}_acc",fontsize=24)
    plt.ylabel('accuracy',fontsize=20)
    plt.xlabel('iteration',fontsize=20)
    
    plt.plot(inf[0],label = "FedAvg")
    plt.plot(inf[1],label = "FedProx")
#     plt.plot(inf[2],label = "ShannonTao")
    plt.plot(inf[4],label = "ShannonWeight")
    plt.plot(inf[3],label = "Grad")
    
    plt.plot(np.array(pickle.load(open(file_path + file3, 'rb')), dtype=object),label = "pFedDGD") # 对比

    plt.legend(loc = "lower right", prop=font1) # 设置信息框    
    
    if mod == 0:
        plt.show()
    else:
        plt.savefig(f"./pic/{name}_acc.png", dpi=300, bbox_inches='tight')
    
    #---------------- loss ----------------#
    file_path = f"./saved_exp_info/server_loss/"
    
    inf = []
    for i in range(len(x)):
        inf.append(np.array(pickle.load(open(file_path + x[i], 'rb')), dtype=object))
    
    plt.figure(figsize=(16, 9)) # 设置整个图像的尺寸（长高分别为6、5个单位）
    plt.title(f"{name}_loss",fontsize=24)
    plt.ylabel('accuracy',fontsize=20)
    plt.xlabel('iteration',fontsize=20)
    
    plt.plot(inf[0],label = "FedAvg")
    plt.plot(inf[1],label = "FedProx")
#     plt.plot(inf[2],label = "ShannonTao")
    plt.plot(inf[4],label = "ShannonWeight")
    plt.plot(inf[3],label = "Grad")
    
    plt.plot(np.array(pickle.load(open(file_path + file3, 'rb')), dtype=object),label = "pFedDGD") #对比
    
    plt.legend(loc = "upper right", prop=font1) # 设置信息框    

    if mod == 0:
        plt.show()
    else:
        plt.savefig(f"./pic/{name}_loss.png", dpi=300, bbox_inches='tight')

# %%
# p2 dn0.1最好
FMNIST = [
    "P0_mu0.0_ld0.0_ln0.0_dN0.0_FMNIST_nbal_0.001_MNIST_Net_lr0.2_d1.0_iter600_expS0.pkl",
    "P0_mu0.5_ld0.0_ln0.0_dN0.0_FMNIST_nbal_0.001_MNIST_Net_lr0.2_d1.0_iter600_expS0.pkl",
    "P1_mu0.0_ld0.0_ln0.0_dN0.0_FMNIST_nbal_0.001_MNIST_Net_lr0.2_d1.0_iter600_expS1.pkl",
    "P2_mu0.0_ld0.0_ln0.1_dN0.998_FMNIST_nbal_0.001_MNIST_Net_lr0.2_d1.0_iter600_expS2.pkl",
    "P-1_mu0.0_ld0.5_ln0.0_dN0.0_FMNIST_nbal_0.001_MNIST_Net_lr0.2_d1.0_iter600_expS3-2.pkl",
]
show1(FMNIST,"P3_mu0.995_ld0.3_ln0.1_dN0.998_FMNIST_nbal_0.001_MNIST_Net_lr0.2_d1.0_iter600_expA3_4.pkl","FMNIST_alpha0.001")

FMNIST = [
    "P0_mu0.0_ld0.0_ln0.0_dN0.0_FMNIST_nbal_0.01_MNIST_Net_lr0.2_d1.0_iter600_expS0.pkl",
    "P0_mu0.5_ld0.0_ln0.0_dN0.0_FMNIST_nbal_0.01_MNIST_Net_lr0.2_d1.0_iter600_expS0.pkl",
    "P1_mu0.0_ld0.0_ln0.0_dN0.0_FMNIST_nbal_0.01_MNIST_Net_lr0.2_d1.0_iter600_expS3.pkl",
    "P2_mu0.0_ld0.0_ln0.1_dN0.998_FMNIST_nbal_0.01_MNIST_Net_lr0.2_d1.0_iter600_expS2-2.pkl",
    "P-1_mu0.0_ld0.5_ln0.0_dN0.0_FMNIST_nbal_0.01_MNIST_Net_lr0.2_d1.0_iter600_expS3-2.pkl",
]
show1(FMNIST,"P3_mu0.995_ld0.3_ln0.1_dN0.998_FMNIST_nbal_0.01_MNIST_Net_lr0.2_d1.0_iter600_expA3_4.pkl","FMNIST_alpha0.01")

# %%
MNIST = [
    "P0_mu0.0_ld0.0_ln0.0_dN0.0_MNIST_nbal_0.001_MNIST_Net_lr0.2_d1.0_iter600_expS0.pkl",
    "P0_mu0.5_ld0.0_ln0.0_dN0.0_MNIST_nbal_0.001_MNIST_Net_lr0.2_d1.0_iter600_expS0.pkl",
    "P1_mu0.0_ld0.0_ln0.0_dN0.0_MNIST_nbal_0.001_MNIST_Net_lr0.2_d1.0_iter600_expS1.pkl",
    "P2_mu0.0_ld0.0_ln0.1_dN0.998_MNIST_nbal_0.001_MNIST_Net_lr0.2_d1.0_iter600_expS2.pkl",
    "P-1_mu0.0_ld0.5_ln0.0_dN0.0_MNIST_nbal_0.001_MNIST_Net_lr0.2_d1.0_iter600_expS3-2.pkl",
]
show1(MNIST,"P3_mu0.995_ld0.3_ln0.1_dN0.998_MNIST_nbal_0.001_MNIST_Net_lr0.2_d1.0_iter600_expA3_4.pkl","MNIST_alpha0.001")

MNIST = [
    "P0_mu0.0_ld0.0_ln0.0_dN0.0_MNIST_nbal_0.01_MNIST_Net_lr0.2_d1.0_iter600_expS0.pkl",
    "P0_mu0.5_ld0.0_ln0.0_dN0.0_MNIST_nbal_0.01_MNIST_Net_lr0.2_d1.0_iter600_expS0.pkl",
    "P1_mu0.0_ld0.0_ln0.0_dN0.0_MNIST_nbal_0.01_MNIST_Net_lr0.2_d1.0_iter600_expS1.pkl",
    "P2_mu0.0_ld0.0_ln0.1_dN0.998_MNIST_nbal_0.01_MNIST_Net_lr0.2_d1.0_iter600_expS2-2.pkl",
    "P-1_mu0.0_ld0.5_ln0.0_dN0.0_MNIST_nbal_0.01_MNIST_Net_lr0.2_d1.0_iter600_expS3-2.pkl",
]
show1(MNIST,"P3_mu0.995_ld0.3_ln0.1_dN0.998_MNIST_nbal_0.01_MNIST_Net_lr0.2_d1.0_iter600_expA3_4.pkl","MNIST_alpha0.01")

# %%
# cifar  avg prox shannon1 grad shannon2
cifars001 = [
    "P0_mu0.0_ld0.0_ln0.0_dN0.0_CIFAR10_nbal_0.001_CIFAR10_CNN_lr0.1_d0.999_iter600_expP0.pkl",
    "P0_mu0.5_ld0.0_ln0.0_dN0.0_CIFAR10_nbal_0.001_CIFAR10_CNN_lr0.1_d1.0_iter600_expP0.pkl",
    "P1_mu0.0_ld2.0_ln0.0_dN0.0_CIFAR10_nbal_0.001_CIFAR10_CNN_lr0.1_d1.0_iter600_expP1.pkl",
    "P2_mu0.0_ld0.0_ln0.2_dN0.998_CIFAR10_nbal_0.001_CIFAR10_CNN_lr0.1_d1.0_iter600_expP2.pkl",
    "P-1_mu0.0_ld0.5_ln0.0_dN0.0_CIFAR10_nbal_0.001_CIFAR10_CNN_lr0.1_d1.0_iter600_expP3.pkl",
]
show1(cifars001,"P3_mu0.99_ld0.7_ln0.2_dN0.998_CIFAR10_nbal_0.001_CIFAR10_CNN_lr0.1_d1.0_iter600_expC2.pkl","CIFAR10_alpha0.001")

cifars01 = [
    "P0_mu0.0_ld0.0_ln0.0_dN0.0_CIFAR10_nbal_0.01_CIFAR10_CNN_lr0.1_d0.999_iter600_expP0.pkl",
    "P0_mu0.5_ld0.0_ln0.0_dN0.0_CIFAR10_nbal_0.01_CIFAR10_CNN_lr0.1_d1.0_iter600_expP0.pkl",
    "P1_mu0.0_ld0.0_ln0.0_dN0.0_CIFAR10_nbal_0.01_CIFAR10_CNN_lr0.1_d1.0_iter600_expP1.pkl",
    "P2_mu0.0_ld0.0_ln0.2_dN0.998_CIFAR10_nbal_0.01_CIFAR10_CNN_lr0.1_d1.0_iter600_expP2.pkl",
    "P-1_mu0.0_ld0.5_ln0.0_dN0.0_CIFAR10_nbal_0.01_CIFAR10_CNN_lr0.1_d1.0_iter600_expP3.pkl",
]
show1(cifars01,"P3_mu0.99_ld0.5_ln0.2_dN0.998_CIFAR10_nbal_0.01_CIFAR10_CNN_lr0.1_d1.0_iter600_expC1.pkl","CIFAR10_alpha0.01")

# %%
# cifar AlexNet avg prox shannon1 grad shannon2
# P3 ld 0.5   ln 0.05试试?
cifarsA001 = [
    "P0_mu0.0_ld0.0_ln0.0_dN0.0_CIFAR10_nbal_0.001_AlexCIFAR10_lr0.2_d0.999_iter1000_expA0_2.pkl",
    "P0_mu0.3_ld0.0_ln0.0_dN0.0_CIFAR10_nbal_0.001_AlexCIFAR10_lr0.2_d0.999_iter1000_expA0_2.pkl",
    "P1_mu0.0_ld2.0_ln0.0_dN0.0_CIFAR10_nbal_0.001_AlexCIFAR10_lr0.2_d1.0_iter1000_expA0.pkl",
    "P2_mu0.0_ld0.0_ln0.1_dN0.998_CIFAR10_nbal_0.001_AlexCIFAR10_lr0.2_d1.0_iter1000_expA0_2.pkl",
    "P-1_mu0.0_ld0.5_ln0.0_dN0.0_CIFAR10_nbal_0.001_AlexCIFAR10_lr0.2_d1.0_iter1000_expA1.pkl",
]
show2(cifarsA001,"P3_mu0.99_ld0.7_ln0.1_dN0.998_CIFAR10_nbal_0.001_AlexCIFAR10_lr0.2_d1.0_iter1000_expC2.pkl","CIFAR10_AlexNet_alpha0.001")

cifarsA01 = [
    "P0_mu0.0_ld0.0_ln0.0_dN0.0_CIFAR10_nbal_0.01_AlexCIFAR10_lr0.2_d0.999_iter1000_expA0_3.pkl",
    "P0_mu0.3_ld0.0_ln0.0_dN0.0_CIFAR10_nbal_0.01_AlexCIFAR10_lr0.2_d0.999_iter1000_expA0_3.pkl",
    "P1_mu0.0_ld2.0_ln0.0_dN0.0_CIFAR10_nbal_0.01_AlexCIFAR10_lr0.2_d1.0_iter1000_expA0.pkl",
    "P2_mu0.0_ld0.0_ln0.1_dN0.998_CIFAR10_nbal_0.01_AlexCIFAR10_lr0.2_d1.0_iter1000_expA0_3.pkl",
    "P-1_mu0.0_ld0.5_ln0.0_dN0.0_CIFAR10_nbal_0.01_AlexCIFAR10_lr0.2_d1.0_iter1000_expA2.pkl",
]
show2(cifarsA01,"P3_mu0.99_ld0.7_ln0.1_dN0.998_CIFAR10_nbal_0.01_AlexCIFAR10_lr0.2_d1.0_iter1000_expC1.pkl","CIFAR10_AlexNet_alpha0.01")
